# %%
import pandas as pd

# %%
cities_df = pd.read_csv('Resources/my_cities.csv')
cities_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Bandarbeyla   9.4942   50.8122     81.27        88          46
# 1           Barrow  71.2906 -156.7887     15.82        79         100
# 2           Albany  42.6001  -73.9662     54.52        92          98
# 3           Ixtapa  20.7000 -105.2000     77.23        78          75
# 4         Corrente  -3.7367  -43.3394     72.68        98         100
# ..             ...      ...       ...       ...       ...         ...
# 569      Maryville  35.7565  -83.9705     70.00        78          75
# 570      Innisfail -17.5333  146.0333     80.89        71           7
# 571  Belle Fourche  44.6714 -103.8522     54.09        73          79
# 572      Manokwari  -0.8667  134.0833     83.82        71          80
# 573    Port-Gentil  -0.7193    8.7815     78.19        87         100
#
#      Wind Speed Country        Date
# 0          4.32      SO  1651716440
# 1         14.97      US  1651716458
# ...

# %%
cities_table = cities_df.to_html()

# %%
cities_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Bandarbeyla</td>\n      <td>9.4942</td>\n      <td>50.8122</td>\n      <td>81.27</td>\n      <td>88</td>\n      <td>46</td>\n      <td>4.32</td>\n      <td>SO</td>\n      <td>1651716440</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Barrow</td>\n      <td>71.2906</td>\n      <td>-156.7887</td>\n      <td>15.82</td>\n      <td>79</td>\n      <td>100</td>\n      <td>14.97</td>\n      <td>US</td>\n      <td>1651716458</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Albany</td>\n      <td>42.6001</td>\n      <td>-73.9662</td>\n      <td>54.52</td>\n      <td>92</td>\n      <td>98</td>\n      <t
# ...
